# %% [markdown]
# 获取股票最新数据

# %%
import akshare as ak

stock_sh_a_spot_em = ak.stock_sh_a_spot_em()
stock_sh_a_spot_em["代码"]+='.SH'
stock_sh_a_spot_em
# Out:
#         序号         代码    名称     最新价     涨跌幅     涨跌额       成交量           成交额  \
# 0        1  688152.SH   N麒麟  215.20  212.38  146.31   87196.0  1.786221e+09
# 1        2  688185.SH   康希诺  188.01   11.38   19.21   87959.0  1.610212e+09
# 2        3  688276.SH  百克生物   64.52   10.37    6.06   52235.0  3.351591e+08
# 3        4  600613.SH  神奇制药    6.36   10.03    0.58  324482.0  1.990422e+08
# 4        5  603232.SH  格尔软件   15.25   10.03    1.39  358857.0  5.404417e+08
# ...    ...        ...   ...     ...     ...     ...       ...           ...
# 2237  2238  688291.SH  C金橙子   28.08  -13.15   -4.25   82112.0  2.446586e+08
# 2238  2239  688353.SH  华盛锂电   63.25  -14.02  -10.31   31754.0  2.065828e+08
# 2239  2240  688670.SH   金迪克   38.29  -14.19   -6.33   16386.0  6.572166e+07
# 2240  2241  688733.SH   壹石通   44.15  -19.27  -10.54   72642.0  3.230257e+08
# 2241  2242  688739.SH  成大生物   33.95  -20.00   -8.49  103909.0  3.598981e+08
#
# ...

# %% [markdown]
# ## notion获取数据，更新

# %%
NOTION_TOKEN = 'secret_LKrQqLcwQ7dQCtDYvsKF2JR7LMGyAYL41753tK5b1kQ'
database_id = 'f70d58252c6e406689e4ea244d64f0ba'

import os
from notion_client import Client

notion = Client(auth=NOTION_TOKEN)

# %%
# 测试
users = notion.users.list()
# print(users)

for user in users.get("results"):
    name, user_type = user["name"], user["type"]
    is_bot = user["type"] == "bot"
    print(f"{name} is a {user_type} {'😅' if is_bot else '🙋‍♂️'}")

# %%
# 获取数据
my_page = notion.databases.query(database_id=database_id)

# %%
# 循环内容

for i in my_page['results']:
    code = i['properties']['code']['rich_text'][0]['plain_text']

# %%
# 修改内容
pages = {
    "现价": 60,
    "目标价":120
}
notion.pages.update(page_id=i["id"],properties=pages)
# Out:
# {'object': 'page',
#  'id': 'f339fcbb-d228-46a5-a510-d733175e22c5',
#  'created_time': '2022-10-30T03:13:00.000Z',
#  'last_edited_time': '2022-10-30T12:32:00.000Z',
#  'created_by': {'object': 'user',
#   'id': 'c71acd89-0feb-4b31-8713-5ddecad10136'},
#  'last_edited_by': {'object': 'user',
#   'id': '214ae8e6-5a75-465d-8723-8ebd10180b9d'},
#  'cover': None,
#  'icon': None,
#  'parent': {'type': 'database_id',
#   'database_id': 'f70d5825-2c6e-4066-89e4-ea244d64f0ba'},
#  'archived': False,
#  'properties': {'现价': {'id': 'IvCL', 'type': 'number', 'number': 60},
#   '收益率': {'id': 'Jvp%3A',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0.5}},
#   'code': {'id': 'PHam',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '002432.SZ', 'link': None},
#      'annotations': {'bold': True,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
# ...

# %% [markdown]
# ## 定时任务

# %%
from apscheduler.schedulers.background import BackgroundScheduler 

def pr():
    print("dsadsadsa")
    
if __name__=='__main__':
    sched = BackgroundScheduler()
    job = sched.add_job(pr,trigger='interval',seconds=2)
    sched.start()
